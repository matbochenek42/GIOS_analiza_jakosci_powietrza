# %% [markdown]
# # Import danych

# %% [markdown]
# Import funkcji z pliku [api_request.py](api_request.py)

# %%
import pandas as pd
from api_request import stations, api_request

# %%
df_stations = stations()
id_stations = df_stations["Identyfikator stacji"].unique().tolist() # lista z id stacji, potrzebne do innych url API
# Out:
# Trwa ładowanie danych z API do DataFrame...
#
# Poprawno załadowano dane ✅

# %% [markdown]
# ### Stanowiska pomiarowe
#
# lista stanowisk pomiarowych dostępnych na wybranej stacji pomiarowej

# %%
df_sensors = api_request("station/sensors/", id_stations, "Lista stanowisk pomiarowych dla podanej stacji") 
id_sensors = df_sensors["Identyfikator stanowiska"].unique().tolist() # lista z id stanowisk, potrzebne do innych url API
# Out:
# Trwa ładowanie danych z API do DataFrame...
#
# Wszystkie wartości dla 'Lista stanowisk pomiarowych dla podanej stacji' zostały załadowane ✅

# %% [markdown]
# ### Dane pomiarowe
#
# dane pomiarowe na podstawie podanego identyfikatora stanowiska pomiarowego

# %%
df_measures = api_request("data/getData/", id_sensors, "Lista danych pomiarowych", item_id = "id_stacji", add_id=True)
# Out:
# Trwa ładowanie danych z API do DataFrame...
#
# Nie udało się połączyć z API dla 'Lista danych pomiarowych'. 66 z 0 wszystkich wartości nie dodano do DataFrame ❌

# %% [markdown]
# ### Indeks jakości powietrza
#
# indeksy jakości powietrza na podstawie podanego identyfikatora stacji pomiarowej

# %%
df_air = api_request("aqindex/getIndex/", id_stations, "AqIndex")
# Out:
# Trwa ładowanie danych z API do DataFrame...
#
# Wszystkie wartości dla 'AqIndex' zostały załadowane ✅

# %% [markdown]
# # 📊 Przegląd danych

# %% [markdown]
# ### Stacje pomiarowe

# %%
print(f"\nLiczba wierszy w df_stations: {len(df_stations)}\n")
# Out:
# 20

# %%
df_stations.sample(5)
# Out:
#     Identyfikator stacji    Kod stacji                         Nazwa stacji  \
# 8                     93  DsSzczaKolej         Szczawno-Zdrój, ul. Kolejowa
# 16                   142  KpGrudPilsud          Grudziądz, ul. Piłsudskiego
# 7                     77  DsPolKasztan            Polkowice, ul. Kasztanowa
# 4                     70  DsOlawZolnAK  Oława, ul. Żołnierzy Armii Krajowej
# 10                   114  DsWrocBartni               Wrocław, ul. Bartnicza
#
#     WGS84 φ N  WGS84 λ E  Identyfikator miasta    Nazwa miasta  \
# 8   50.804189  16.254111                   915  Szczawno-Zdrój
# 16  53.493550  18.762139                   269       Grudziądz
# 7   51.502370  16.075051                   721       Polkowice
# 4   50.942073  17.291333                   642           Oława
# 10  51.115933  17.141125                  1064         Wrocław
#
#              Gmina      Powiat         Województwo                Ulica
# 8   Szczawno-Zdrój  wałbrzyski        DOLNOŚLĄSKIE      ul. Kolejowa 14
# 16       Grudziądz   Grudziądz  KUJAWSKO-POMORSKIE  ul. Piłsudskiego 51
# 7        Polkowice  polkowicki        DOLNOŚLĄSKIE    ul. Kasztanowa 29
# 4            Oława     oławski        DOLNOŚLĄSKIE   ul. Żołnierzy AK 9
# 10         Wrocław     Wrocław        DOLNOŚLĄSKIE        ul. Bartnicza

# %% [markdown]
# ### Stanowiska pomiarowe

# %%
print(f"\nLiczba wierszy w df_sensors: {len(df_sensors)}\n")
# Out:
# 123

# %%
df_sensors.sample(5)
# Out:
#     Identyfikator stanowiska  Identyfikator stacji                 Wskaźnik  \
# 78                     32600                   109     pył zawieszony PM2.5
# 7                        221                    38          dwutlenek azotu
# 97                       665                   117          dwutlenek azotu
# 36                       411                    74  arsen (całk. depozycja)
# 74                       618                   109      pył zawieszony PM10
#
#    Wskaźnik - wzór Wskaźnik - kod  Id wskaźnika
# 78           PM2.5          PM2.5            69
# 7              NO2            NO2             6
# 97             NO2            NO2             6
# 36      As(cdepoz)     As(cdepoz)            82
# 74            PM10           PM10             3

# %% [markdown]
# ### Dane pomiarowe

# %%
print(f"\nLiczba wierszy w df_measures: {len(df_measures)}\n")
# Out:
# 1140

# %%
df_measures.sample(5)
# Out:
#             Kod stanowiska                 Data  Wartość  id_stacji  \
# 949     DsWrocAlWisn-NO-1g  2026-05-30 07:00:00     39.1        739
# 1056   KpGrudPilsud-NO2-1g  2026-05-30 00:00:00     22.2        809
# 73      DsCzerStraza-O3-1g  2026-05-30 03:00:00    120.3         52
# 476   DsOlawZolnAK-PM10-1g  2026-05-30 00:00:00     25.1        400
# 18      DsCzerStraza-NO-1g  2026-05-29 22:00:00      0.5         49
#
#                    data_dodania
# 949  2026-05-30 16:02:18.737198
# 1056 2026-05-30 16:02:19.074413
# 73   2026-05-30 16:02:10.125774
# 476  2026-05-30 16:02:15.088020
# 18   2026-05-30 16:02:09.669719

# %%
df_measures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1140 entries, 0 to 1139
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Kod stanowiska  1140 non-null   object
#  1   Data            1140 non-null   object
#  2   Wartość         1065 non-null   float64
#  3   id_stacji       1140 non-null   int64
#  4   data_dodania    1140 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 44.7+ KB

# %% [markdown]
# ### Indeks jakości powietrza

# %%
print(f"\nLiczba wierszy w df_air: {len(df_air)}\n")
# Out:
# 20

# %%
df_air.sample(5)
# Out:
#     Identyfikator stacji pomiarowej Data wykonania obliczeń indeksu  \
# 1                              16.0             2026-05-30 15:20:11
# 6                              74.0             2026-05-30 15:20:11
# 18                            145.0             2026-05-30 15:35:13
# 5                               NaN                            None
# 3                              52.0             2026-05-30 15:20:11
#
#     Wartość indeksu Nazwa kategorii indeksu  \
# 1              -1.0            Brak indeksu
# 6               1.0                   Dobry
# 18             -1.0            Brak indeksu
# 5               NaN                    None
# 3               1.0                   Dobry
#
#    Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika st  \
# 1                                 2026-05-30 14:00:00
# 6                                 2026-05-30 15:00:00
# 18                                2026-05-30 15:00:00
# 5                                                None
# 3                                 2026-05-30 15:00:00
#
#    Data wykonania obliczeń indeksu dla wskaźnika SO2  \
# 1                                2026-05-30 15:20:11
# 6                                2026-05-30 15:20:11
# 18                               2026-05-30 15:35:13
# 5                                               None
# 3                                2026-05-30 15:20:11
#
#     Wartość indeksu dla wskaźnika SO2  \
# 1                                 NaN
# 6                                 0.0
# 18                                NaN
# 5                                 NaN
# 3                                 0.0
#
#    Nazwa kategorii indeksu dla wskażnika SO2  \
# 1                                       None
# 6                               Bardzo dobry
# 18                                      None
# 5                                       None
# 3                               Bardzo dobry
#
#    Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika SO2  \
# 1                                                None
# 6                                 2026-05-30 15:00:00
# 18                                               None
# 5                                                None
# 3                                 2026-05-30 15:00:00
#
#    Data wykonania obliczeń indeksu dla wskaźnika NO2  ...  \
# 1                                2026-05-30 15:20:11  ...
# 6                                2026-05-30 15:20:11  ...
# 18                               2026-05-30 15:35:13  ...
# 5                                               None  ...
# 3                                2026-05-30 15:20:11  ...
#
#     Data wykonania obliczeń indeksu dla wskaźnika PM2.5  \
# 1                                                None
# 6                                 2026-05-30 15:20:11
# 18                                               None
# 5                                                None
# 3                                 2026-05-30 15:20:11
#
#    Wartość indeksu dla wskaźnika PM2.5  \
# 1                                  NaN
# 6                                  NaN
# 18                                 NaN
# 5                                  NaN
# 3                                  0.0
#
#    Nazwa kategorii indeksu dla wskażnika PM2.5  \
# 1                                         None
# 6                                         None
# 18                                        None
# 5                                         None
# 3                                 Bardzo dobry
#
#    Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika PM2.5  \
# 1                                                None
# 6                                                None
# 18                                               None
# 5                                                None
# 3                                 2026-05-30 15:00:00
#
#     Data wykonania obliczeń indeksu dla wskaźnika O3  \
# 1                                               None
# 6                                2026-05-30 15:20:11
# 18                                              None
# 5                                               None
# 3                                2026-05-30 15:20:11
#
#    Wartość indeksu dla wskaźnika O3 Nazwa kategorii indeksu dla wskażnika O3  \
# 1                               NaN                                     None
# 6                               1.0                                    Dobry
# 18                              NaN                                     None
# 5                               NaN                                     None
# 3                               1.0                                    Dobry
#
#    Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika O3  \
# 1                                                None
# 6                                 2026-05-30 15:00:00
# 18                                               None
# 5                                                None
# 3                                 2026-05-30 15:00:00
#
#     Status indeksu ogólnego dla stacji pomiarowej  \
# 1                                           False
# 6                                            True
# 18                                          False
# 5                                            None
# 3                                            True
#
#    Kod zanieczyszczenia krytycznego
# 1                              OZON
# 6                              OZON
# 18                             OZON
# 5                              None
# 3                              OZON
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 🧹 Czyszczenie danych

# %%
# zmiana nazw kolumn
df_stations.rename(columns={
    "WGS84 φ N": "Szerokość geograficzna (N)",
    "WGS84 λ E": "Długość geograficzna (E)"
}, inplace=True)

# %%
# zmiana nazw kolumn (kod wygenerowany przez czat GPT)

df_air = df_air.rename(columns={
    'Identyfikator stacji pomiarowej': 'id_stacji',
    'Data wykonania obliczeń indeksu': 'data_obliczenia',
    'Wartość indeksu': 'wartosc_indeksu',
    'Nazwa kategorii indeksu': 'kategoria_indeksu',

    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika st': 'data_zrodlowa',

    'Data wykonania obliczeń indeksu dla wskaźnika SO2': 'so2_data_obliczenia',
    'Wartość indeksu dla wskaźnika SO2': 'so2_wartosc',
    'Nazwa kategorii indeksu dla wskażnika SO2': 'so2_kategoria',
    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika SO2': 'so2_data_zrodlowa',

    'Data wykonania obliczeń indeksu dla wskaźnika NO2': 'no2_data_obliczenia',
    'Wartość indeksu dla wskaźnika NO2': 'no2_wartosc',
    'Nazwa kategorii indeksu dla wskażnika NO2': 'no2_kategoria',
    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika NO2': 'no2_data_zrodlowa',

    'Data wykonania obliczeń indeksu dla wskaźnika PM10': 'pm10_data_obliczenia',
    'Wartość indeksu dla wskaźnika PM10': 'pm10_wartosc',
    'Nazwa kategorii indeksu dla wskażnika PM10': 'pm10_kategoria',
    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika PM10': 'pm10_data_zrodlowa',

    'Data wykonania obliczeń indeksu dla wskaźnika PM2.5': 'pm25_data_obliczenia',
    'Wartość indeksu dla wskaźnika PM2.5': 'pm25_wartosc',
    'Nazwa kategorii indeksu dla wskażnika PM2.5': 'pm25_kategoria',
    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika PM2.5': 'pm25_data_zrodlowa',

    'Data wykonania obliczeń indeksu dla wskaźnika O3': 'o3_data_obliczenia',
    'Wartość indeksu dla wskaźnika O3': 'o3_wartosc',
    'Nazwa kategorii indeksu dla wskażnika O3': 'o3_kategoria',
    'Data danych źródłowych, z których policzono wartość indeksu dla wskaźnika O3': 'o3_data_zrodlowa',

    'Status indeksu ogólnego dla stacji pomiarowej': 'status_stacji',
    'Kod zanieczyszczenia krytycznego': 'krytyczne_zanieczyszczenie'
})

# %%
# usuwanie ewentualnych pustych wierszy

df_stations.dropna(subset=["Identyfikator stacji"], inplace=True)
df_sensors.dropna(subset=["Identyfikator stanowiska", "Identyfikator stacji"], inplace=True) 
df_measures.dropna(subset=["Kod stanowiska"], inplace=True)
df_air.dropna(subset=["id_stacji"], inplace=True)

# %%
# usuwanie ewentualnych duplikatów

df_stations.drop_duplicates(inplace=True, subset=["Identyfikator stacji"])
df_sensors.drop_duplicates(inplace=True, subset=["Identyfikator stanowiska", "Identyfikator stacji"])
df_measures.drop_duplicates(inplace=True, subset=["Kod stanowiska", "Data"])
df_air.drop_duplicates(inplace=True, subset=["id_stacji", "data_obliczenia"])

# %%
# usuwanie drukowanych liter
df_stations["Województwo"] = df_stations["Województwo"].str.capitalize()

# %%
df_stations.sample(3)
# Out:
#     Identyfikator stacji    Kod stacji                           Nazwa stacji  \
# 9                    109  DsWalbrzWyso              Wałbrzych, ul. Wysockiego
# 0                     11  DsCzerStraza                              Czerniawa
# 12                   117  DsWrocWybCon  Wrocław, wyb. Conrada-Korzeniowskiego
#
#    Szerokość geograficzna (N) Długość geograficzna (N)  Identyfikator miasta  \
# 9                   50.768729                16.269677                   998
# 0                   50.912475                15.312190                   142
# 12                  51.129378                17.029250                  1064
#
#    Nazwa miasta            Gmina     Powiat   Województwo  \
# 9     Wałbrzych        Wałbrzych  Wałbrzych  Dolnośląskie
# 0     Czerniawa  Świeradów-Zdrój   lubański  Dolnośląskie
# 12      Wrocław          Wrocław    Wrocław  Dolnośląskie
#
#                                     Ulica
# 9                       ul. Wysockiego 11
# 0                         ul. Strażacka 7
# 12  ul. Wyb. J.Conrada-Korzeniowskiego 18

# %%
# konwersja wartości float na int

df_air["id_stacji"] = df_air["id_stacji"].astype(int)

cols = ["wartosc_indeksu", "so2_wartosc", "no2_wartosc", "pm10_wartosc", "pm25_wartosc", "o3_wartosc"]

df_air[cols] = df_air[cols].astype("Int64")

# %%
df_air.sample(3)
# Out:
#     id_stacji      data_obliczenia  wartosc_indeksu kategoria_indeksu  \
# 9         109  2026-05-30 15:20:11                1             Dobry
# 17        143  2026-05-30 15:35:13               -1      Brak indeksu
# 0          11  2026-05-30 15:20:11                1             Dobry
#
#           data_zrodlowa  so2_data_obliczenia  so2_wartosc so2_kategoria  \
# 9   2026-05-30 15:00:00  2026-05-30 15:20:11            0  Bardzo dobry
# 17  2026-05-30 15:00:00  2026-05-30 15:35:13         <NA>          None
# 0   2026-05-30 15:00:00  2026-05-30 15:20:11         <NA>          None
#
#       so2_data_zrodlowa  no2_data_obliczenia  ...  pm25_data_obliczenia  \
# 9   2026-05-30 15:00:00  2026-05-30 15:20:11  ...   2026-05-30 15:20:11
# 17                 None  2026-05-30 15:35:13  ...                  None
# 0                  None  2026-05-30 15:20:11  ...                  None
#
#    pm25_wartosc pm25_kategoria   pm25_data_zrodlowa   o3_data_obliczenia  \
# 9             0   Bardzo dobry  2026-05-30 15:00:00  2026-05-30 15:20:11
# 17         <NA>           None                 None                 None
# 0          <NA>           None                 None  2026-05-30 15:20:11
#
#    o3_wartosc o3_kategoria     o3_data_zrodlowa  status_stacji  \
# 9           1        Dobry  2026-05-30 15:00:00           True
# 17       <NA>         None                 None          False
# 0           1        Dobry  2026-05-30 15:00:00           True
#
#    krytyczne_zanieczyszczenie
# 9                        OZON
# 17                       OZON
# 0                        OZON
#
# [3 rows x 27 columns]
